# %% [markdown]
# <h1 style="text-align: center;">
#   <b>Seleção de Modelos de Machine Learning em Dados Multivariados e Anonimizados</b>
# </h1>
#
# <p style='text-align: justify;'>
#   _______________________________________________________________________________________________________
# </p>
#
# <h2 style='text-align: justify;'>
#   Machine Learning para um Problema de Classificação Supervisionada.
# </h2>
#
# <h3 style="text-align: justify;">
#   Script desenvolvido para explorar diferentes técnicas de seleção de modelos de Machine Learning para identificar o algoritmo mais eficaz e eficiente, em um ambiente com dados multivariados e anonimizados.
# </h3>
#
# <p style='text-align: justify;'>
#   Nosso trabalho é construir um modelo de Machine Learning capaz de prever se o cliente de  uma  seguradora  vai  renovar  ou  não  o  seguro  do  carro.  Com  esse  modelo  preditivo  a seguradora pode planejar melhor seu orçamento prevendo antecipadamente a renovação de um determinado cliente a qualquer momento.
# </p>
#
# <p style='text-align: justify;'>
#   Por motivos de privacidade, não são fornecidas informações sobre a fonte de dados nem sobre os nomes das 178 variáveis descritivas que representam as caracteristicas dos clientes. Não  é  possível  identificar  o  que  cada  característica representa  e  os dados tratados nesse projeto já estão anonimizados.  A  variável  179  é  a variável LABEL_TARGET,  ela indica se o cliente renovou ou não o seguro nos 2 anos anteriores.
# </p>
#
# <p style='text-align: justify;'>
#   Neste projeto, dividimos as análises em duas partes contidas em dois scripts python: a parte 1 trata do pré-processamento dos dados e a parte 2 trata da modelagem.
# </p>
#
# <p style='text-align: justify;'>
#   _______________________________________________________________________________________________________
# </p>

# %% [markdown]
# <h2 style='text-align: justify;'>
#   Parte 1: Pré-Processamento dos Dados
# </h2>
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
# Imports
import pandas as pd
import numpy as np
import pickle

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Michela Camboim"
# Out:
# Author: Michela Camboim

# %% [markdown]
# <p style='text-align: justify;'>
#   ________________________________________
# </p>
#
# <h4 style='text-align: justify;'>
# Carregando os dados
# </h4>
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
# Carregando os dados
df = pd.read_csv("dados/dataset.csv")

print(f'Shape: ', df.shape)

df.head()
# Out:
# Shape:  (11500, 179)
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  X172  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15   -31
# 1  386  382  356  331  320  315  307  272  244  232  ...   164   150   146
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64    48
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81   -80
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2   -12
#
#    X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 0   -77  -103  -127  -116   -83   -51         False
# 1   152   157   156   154   143   129          True
# 2    19   -12   -30   -35   -35   -36         False
# 3   -77   -85   -77   -72   -69   -65         False
# 4   -32   -41   -65   -83   -89   -73         False
#
# [5 rows x 179 columns]

# %% [markdown]
# <p style='text-align: justify;'>
#   ________________________________________
# </p>
#
# <h4 style='text-align: justify;'>
# Análise Exploratória e Limpeza de Dados
# </h4>
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
# Categorias da variável alvo
df.LABEL_TARGET.value_counts()
# Out:
# False    9200
# True     2300
# Name: LABEL_TARGET, dtype: int64

# %%
# Converte de string para valor numérico
df["LABEL_TARGET"] = df["LABEL_TARGET"].astype(int)

# %%
# Visualizando alguns registros
df.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  X172  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15   -31
# 1  386  382  356  331  320  315  307  272  244  232  ...   164   150   146
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64    48
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81   -80
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2   -12
#
#    X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 0   -77  -103  -127  -116   -83   -51             0
# 1   152   157   156   154   143   129             1
# 2    19   -12   -30   -35   -35   -36             0
# 3   -77   -85   -77   -72   -69   -65             0
# 4   -32   -41   -65   -83   -89   -73             0
#
# [5 rows x 179 columns]

# %%
# Resumo estatístico
df.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# std      161.328725    161.467837    162.11912    162.03336    160.436352
# min    -1757.000000  -1832.000000  -1778.00000  -1840.00000  -1867.000000
# 25%      -54.000000    -54.000000    -55.00000    -55.00000    -54.000000
# 50%       -8.000000     -8.000000     -8.00000     -7.00000     -7.000000
# 75%       36.000000     35.000000     36.00000     36.00000     35.250000
# max     1816.000000   2047.000000   2047.00000   2047.00000   2047.000000
#
#        ...          X170          X171          X172          X173  \
# count  ...  11500.000000  11500.000000  11500.000000  11500.000000
# mean   ...    -10.145739    -11.630348    -12.943478    -13.668870
# std    ...    164.652883    166.149790    168.554058    168.556486
# min    ...  -1867.000000  -1865.000000  -1642.000000  -1723.000000
# 25%    ...    -55.000000    -56.000000    -56.000000    -56.000000
# 50%    ...     -9.000000    -10.000000    -10.000000    -10.000000
# 75%    ...     34.000000     34.000000     33.000000     33.000000
# max    ...   1777.000000   1472.000000   1319.000000   1436.000000
#
#                X174          X175          X176          X177          X178  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -13.363304    -13.045043    -12.705130    -12.426000    -12.195652
# std      167.257290    164.241019    162.895832    162.886311    164.852015
# min    -1866.000000  -1863.000000  -1781.000000  -1727.000000  -1829.000000
# 25%      -55.000000    -56.000000    -55.000000    -55.000000    -55.000000
# 50%      -10.000000     -9.000000     -9.000000     -9.000000     -9.000000
# 75%       34.000000     34.000000     34.000000     34.000000     34.000000
# max     1733.000000   1958.000000   2047.000000   2047.000000   1915.000000
#
#        LABEL_TARGET
# count  11500.000000
# mean       0.200000
# std        0.400017
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 179 columns]

# %%
# Verificando se há valores ausentes
df.isnull().values.any()
# Out:
# False

# %%
# Extrai a lista de colunas
lista_de_colunas = df.columns.tolist()

# %%
# Colunas das variáveis de entrada (input)
colunas_entrada = lista_de_colunas[0:178]

# %%
print(colunas_entrada)
# Out:
# ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31', 'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40', 'X41', 'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49', 'X50', 'X51', 'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59', 'X60', 'X61', 'X62', 'X63', 'X64', 'X65', 'X66', 'X67', 'X68', 'X69', 'X70', 'X71', 'X72', 'X73', 'X74', 'X75', 'X76', 'X77', 'X78', 'X79', 'X80', 'X81', 'X82', 'X83', 'X84', 'X85', 'X86', 'X87', 'X88', 'X89', 'X90', 'X91', 'X92', 'X93', 'X94', 'X95', 'X96', 'X97', 'X98', 'X99', 'X100', 'X101', 'X102', 'X103', 'X104', 'X105', 'X106', 'X107', 'X108', 'X109', 'X110', 'X111', 'X112', 'X113', 'X114', 'X115', 'X116', 'X117', 'X118', 'X119', 'X120', 'X121', 'X122', 'X123', 'X124', 'X125', 'X126', 'X127', 'X128', 'X129', 'X130', 'X131', 'X132', 'X133', 'X134', 'X135', 'X136', 'X137', 'X138', 'X139', 'X140', 'X141', 'X142', 'X143', 'X144', 'X145', 'X146', 'X147', 'X148', 'X149', 'X150', 'X151', 'X152', 'X153', 'X154', 'X155', 'X156', 'X157', 'X158', 'X159', 'X160', 'X161', 'X162', 'X163', 'X164', 'X165', 'X166', 'X167', 'X168', 'X169', 'X170', 'X171', 'X172', 'X173', 'X174', 'X175', 'X176', 'X177', 'X178']

# %%
# Checando se temos colunas duplicadas nos dados de entrada
dup_cols = set([x for x in colunas_entrada if colunas_entrada.count(x) > 1])
print(dup_cols)
assert len(dup_cols) == 0, "você duplicou colunas em cols_input"
# Out:
# set()

# %%
# Checando se temos colunas duplicadas no dataset completo
dup_cols = set([x for x in lista_de_colunas if lista_de_colunas.count(x) > 1])
print(dup_cols)
assert len(dup_cols) == 0,'você duplicou colunas em lista_de_colunas'
# Out:
# set()

# %%
# Categorias da variável alvo
df.LABEL_TARGET.value_counts(normalize=True)
# Out:
# 0    0.8
# 1    0.2
# Name: LABEL_TARGET, dtype: float64

# %% [markdown]
# <p style='text-align: justify;'>
#   ________________________________________
# </p>
#
# <p style='text-align: justify;'>
# A prevalência é a porcentagem das amostras que têm a característica que se está tentando prever. Em nosso caso, significa que as pessoas que renovaram o seguro são da classe positiva (ocorrência do evento = 1) e quem não comprou é da classe negativa (não ocorreu o evento = 0).
# </p>
#
# <p style='text-align: justify;'>
# Os termos positivo e negativo não têm conotação de coisa boa ou ruim. É apenas a nomenclatura usada para indicar a ocorrência ou não do evento.
# </p>
#
# <p style='text-align: justify;'>
# A taxa é calculada por (número de amostras positivas / número de amostras). Portanto, uma taxa de prevalência de 0,2 significa que 20% de nossa amostra renovou o seguro do carro.
# </p>
#
# <p style='text-align: justify;'>
# O desbalanceamento de classe é um problema que terá que ser resolvido durante o pré-processamento dos dados.
# </p>
#
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
# Esta função calcula a prevalência da classe positiva (label = 1)
def calcula_prevalencia(y_actual):
    return sum(y_actual) / len(y_actual)

# %%
print("Prevalência da classe positiva: %.3f"% calcula_prevalencia(df["LABEL_TARGET"].values))
# Out:
# Prevalência da classe positiva: 0.200

# %% [markdown]
# <p style='text-align: justify;'>
#   ________________________________________
# </p>
#
# <h4 style='text-align: justify;'>
# Divisão dos Dados em Treino, Teste e Validação, Mantendo a Prevalência de Classe
# </h4>
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
# Gerando amostras aleatórias dos dados, embaralha dados
df_data = df.sample(n = len(df))

df_data
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 1696   -94 -106 -116 -114  -94  -65  -39  -15    1   10  ...   -30   -26
# 27    -340 -381 -376 -336 -275 -204 -131  -70  -16   20  ...   114   -39
# 11329  -98  -89  -73  -62  -46  -33  -51  -66  -78  -59  ...    60    18
# 11356   13   25   19   18    8   12   14   10   16   43  ...   -61   -65
# 8551   103  465  689  697  655  642  618  566  533  522  ...   475   443
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 6618    17  -24  -61  -81  -84  -72  -69  -60  -55  -40  ...    -4    20
# 9009    -2    2   13   51   76   97   70   40   17    1  ...    34    25
# 10871   -4  -12  -10  -21  -12   -3    0  -15  -18  -32  ...  -103   -97
# 6769     2    5    7    3   -3   -3   -2    7    8   -1  ...   123   111
# 844     30   32   35   39   41   42   41   37   37   37  ...    57    58
#
#        X172  X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 1696    -25   -36   -59   -78  -100  -118  -124             0
# 27     -185  -293  -351  -379  -380  -350  -308             1
# 11329     3    -6   -20   -50   -70   -65   -48             0
# 11356   -57   -47   -38   -40   -37   -35   -44             0
# 8551    390   314   173  -258  -720 -1094 -1168             1
# ...     ...   ...   ...   ...   ...   ...   ...           ...
# 6618     38    40     6   -55   -99   -99   -47             0
# 9009     22    13    11     8    15    24     9             0
# 10871   -85   -78   -64   -51   -38   -51   -62             0
# 6769    120   138   149   144   143   151   157             0
# 844      52    53    52    52    53    53    53             0
#
# [11500 rows x 179 columns]

# %%
# Ajustando os índices do dataset
df_data = df_data.reset_index(drop = True)

# %%
df_data
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 0      -94 -106 -116 -114  -94  -65  -39  -15    1   10  ...   -30   -26
# 1     -340 -381 -376 -336 -275 -204 -131  -70  -16   20  ...   114   -39
# 2      -98  -89  -73  -62  -46  -33  -51  -66  -78  -59  ...    60    18
# 3       13   25   19   18    8   12   14   10   16   43  ...   -61   -65
# 4      103  465  689  697  655  642  618  566  533  522  ...   475   443
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11495   17  -24  -61  -81  -84  -72  -69  -60  -55  -40  ...    -4    20
# 11496   -2    2   13   51   76   97   70   40   17    1  ...    34    25
# 11497   -4  -12  -10  -21  -12   -3    0  -15  -18  -32  ...  -103   -97
# 11498    2    5    7    3   -3   -3   -2    7    8   -1  ...   123   111
# 11499   30   32   35   39   41   42   41   37   37   37  ...    57    58
#
#        X172  X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 0       -25   -36   -59   -78  -100  -118  -124             0
# 1      -185  -293  -351  -379  -380  -350  -308             1
# 2         3    -6   -20   -50   -70   -65   -48             0
# 3       -57   -47   -38   -40   -37   -35   -44             0
# 4       390   314   173  -258  -720 -1094 -1168             1
# ...     ...   ...   ...   ...   ...   ...   ...           ...
# 11495    38    40     6   -55   -99   -99   -47             0
# 11496    22    13    11     8    15    24     9             0
# 11497   -85   -78   -64   -51   -38   -51   -62             0
# 11498   120   138   149   144   143   151   157             0
# 11499    52    53    52    52    53    53    53             0
#
# [11500 rows x 179 columns]

# %%
# Extrai uma amostra de 30% dos dados de forma aleatória
df_amostra_30 = df_data.sample(frac = 0.3)

df_amostra_30
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 2692   451  522  563  575  568  505  373  142 -197 -547  ...  -832  -664
# 2023  -193 -225 -258 -297 -353 -303 -133  153  343  290  ...   346   221
# 10860   55   38   26   20   24   25   28   14    4    1  ...    45    35
# 4655   224  219  198  177  152  126  107   92   82   77  ...   -95   -92
# 4687   -61 -103 -130 -130 -107  -83  -56  -19   19   49  ...   122    27
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 2766    24   18    8  -11  -40  -46  -50  -56  -46  -39  ...    27    33
# 8893   -61  -77  -80  -69  -62  -42  -30  -34  -22  -17  ...    37    48
# 5077    72   93  101   94   93  144  111   13   -3    5  ...    56    54
# 7780  -847 -703 -529 -378 -269 -182 -110  -35   40  113  ...  -288  -744
# 9460   -59  -20   14   27   15    5   -6   -2   -2   -3  ...   -25   -61
#
#        X172  X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 2692   -509  -363  -238  -138   -50    25   110             1
# 2023    151   122   133   163   193   228   253             1
# 10860    30    28    27    24     5   -14   -35             0
# 4655    -82   -63   -51   -47   -33   -12     1             0
# 4687    -76  -177  -217  -202  -137   -74   -23             0
# ...     ...   ...   ...   ...   ...   ...   ...           ...
# 2766     23    34    29    10   -10   -16   -20             0
# 8893     65    65    67    66    68    70    58             0
# 5077     87    81    38    42    25   -16   -31             0
# 7780  -1062 -1170 -1106  -963  -786  -615  -478             1
# 9460    -87  -110  -105   -78   -31     8    28             0
#
# [3450 rows x 179 columns]

# %%
# Fazendo a divisão

# Dados de teste
df_teste = df_amostra_30.sample(frac = 0.5) # 15% dados de teste

# Dados se validação
df_valid = df_amostra_30.drop(df_teste.index) # 15% dados de validação

# Dados de treino
df_treino = df_data.drop(df_amostra_30.index) # 70% dados de treino

print(f'Shape df_teste: {df_teste.shape}')
print(f'Shape df_valid: {df_valid.shape}')
print(f'Shape df_treino: {df_treino.shape}')
# Out:
# Shape df_teste: (1725, 179)
# Shape df_valid: (1725, 179)
# Shape df_treino: (8050, 179)

# %%
df_teste
# Out:
#         X1   X2   X3   X4   X5   X6  X7  X8   X9  X10  ...  X170  X171  X172  \
# 4639   -17  -19  -25  -33  -43  -56 -64 -69  -70  -75  ...   -74   -86  -100
# 3170    87   71   34   -9  -50  -70 -66 -44  -23   24  ...    55    23   -20
# 2575   -20  -35  -36  -21  -10  -10  -9  -5  -11  -16  ...   -32   -34   -32
# 10718    3    3    6   12   15   23  25  26   22   23  ...    27    19    14
# 4881   -33  -37  -48  -56  -69  -88 -97 -97  -75  -51  ...    13     3   -12
# ...    ...  ...  ...  ...  ...  ...  ..  ..  ...  ...  ...   ...   ...   ...
# 4249   -22  -27  -47  -59  -59  -52 -36 -28  -31  -36  ...   -21   -38   -56
# 9400   512  525  525  422  322  191  89 -13 -102 -163  ...   302   270   209
# 8202    48   38   18   13   18   29  30  20    9    0  ...   109   125   136
# 512    -12  -36  -49  -21    4   -4  20  55   69   74  ...    32    39    27
# 1958   -84  -81  -80  -69  -59  -46 -38 -26  -27  -24  ...   -17   -15   -19
#
#        X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 4639   -115  -124  -135  -141  -145  -144             0
# 3170    -68  -107  -125   -96   -52     7             0
# 2575    -27   -24   -20   -14    10    39             0
# 10718    10    13    19    20    27    26             0
# 4881    -19   -15    -1    14    36    47             0
# ...     ...   ...   ...   ...   ...   ...           ...
# 4249    -70   -69   -43   -20    17    46             0
# 9400    163   131   121   109    78    50             1
# 8202    135   122   104    71    47    36             0
# 512      16     9     9   -12   -12    -1             0
# 1958    -34   -42   -57   -62   -67   -60             0
#
# [1725 rows x 179 columns]

# %%
df_valid
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 2692   451  522  563  575  568  505  373  142 -197 -547  ...  -832  -664
# 2023  -193 -225 -258 -297 -353 -303 -133  153  343  290  ...   346   221
# 10860   55   38   26   20   24   25   28   14    4    1  ...    45    35
# 4687   -61 -103 -130 -130 -107  -83  -56  -19   19   49  ...   122    27
# 11290   36   28   23   15   18   18   20   19   13   10  ...    39    31
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 1053   -38  -17    9   39   62   42  -12  -33   23  120  ...    83    68
# 8893   -61  -77  -80  -69  -62  -42  -30  -34  -22  -17  ...    37    48
# 5077    72   93  101   94   93  144  111   13   -3    5  ...    56    54
# 7780  -847 -703 -529 -378 -269 -182 -110  -35   40  113  ...  -288  -744
# 9460   -59  -20   14   27   15    5   -6   -2   -2   -3  ...   -25   -61
#
#        X172  X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 2692   -509  -363  -238  -138   -50    25   110             1
# 2023    151   122   133   163   193   228   253             1
# 10860    30    28    27    24     5   -14   -35             0
# 4687    -76  -177  -217  -202  -137   -74   -23             0
# 11290    18    13     6     6     3    -1     3             0
# ...     ...   ...   ...   ...   ...   ...   ...           ...
# 1053     55    28     3    -8   -26   -35   -35             1
# 8893     65    65    67    66    68    70    58             0
# 5077     87    81    38    42    25   -16   -31             0
# 7780  -1062 -1170 -1106  -963  -786  -615  -478             1
# 9460    -87  -110  -105   -78   -31     8    28             0
#
# [1725 rows x 179 columns]

# %%
df_treino
# Out:
#         X1   X2   X3   X4   X5   X6   X7  X8  X9  X10  ...  X170  X171  X172  \
# 0      -94 -106 -116 -114  -94  -65  -39 -15   1   10  ...   -30   -26   -25
# 1     -340 -381 -376 -336 -275 -204 -131 -70 -16   20  ...   114   -39  -185
# 2      -98  -89  -73  -62  -46  -33  -51 -66 -78  -59  ...    60    18     3
# 5      -50  -55  -50  -49  -46  -48  -41 -45 -52  -60  ...   -32   -32   -36
# 6       11  -30  -66  -99 -108 -100  -89 -88 -94  -95  ...   -98   -90   -68
# ...    ...  ...  ...  ...  ...  ...  ...  ..  ..  ...  ...   ...   ...   ...
# 11492  110   83   75   79   87   89   53  31 -13  -32  ...    33    50    66
# 11494    2  -15  -11   19   30   53   25  -4 -28  -47  ...    30    26    11
# 11495   17  -24  -61  -81  -84  -72  -69 -60 -55  -40  ...    -4    20    38
# 11496   -2    2   13   51   76   97   70  40  17    1  ...    34    25    22
# 11497   -4  -12  -10  -21  -12   -3    0 -15 -18  -32  ...  -103   -97   -85
#
#        X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 0       -36   -59   -78  -100  -118  -124             0
# 1      -293  -351  -379  -380  -350  -308             1
# 2        -6   -20   -50   -70   -65   -48             0
# 5       -33   -27   -19   -11    -8    -6             0
# 6       -52   -45   -50   -59   -57   -35             0
# ...     ...   ...   ...   ...   ...   ...           ...
# 11492    63    54    46    42    46    52             0
# 11494    16    -5   -11   -23   -17   -11             0
# 11495    40     6   -55   -99   -99   -47             0
# 11496    13    11     8    15    24     9             0
# 11497   -78   -64   -51   -38   -51   -62             0
#
# [8050 rows x 179 columns]

# %%
# analisando a prevalência das amostras geradas

print(f'Teste, {df_teste.LABEL_TARGET.value_counts(normalize=True)}')
print(f'Validação, {df_valid.LABEL_TARGET.value_counts(normalize=True)}')
print(f'Treino, {df_treino.LABEL_TARGET.value_counts(normalize=True)}')
# Out:
# Teste, 0    0.805217
# 1    0.194783
# Name: LABEL_TARGET, dtype: float64
# Validação, 0    0.792464
# 1    0.207536
# Name: LABEL_TARGET, dtype: float64
# Treino, 0    0.800497
# 1    0.199503
# Name: LABEL_TARGET, dtype: float64

# %% [markdown]
# <p style='text-align: justify;'>
#   ________________________________________
# </p>
#
# <h4 style='text-align: justify;'>
# Balanceamento de Classe nos Dados de Treino. Estratégia Undersampling.
# </h4>
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
df_treino.shape
# Out:
# (8050, 179)

# %%
df_treino.LABEL_TARGET.value_counts()
# Out:
# 0    6444
# 1    1606
# Name: LABEL_TARGET, dtype: int64

# %%
# Cria um índice com True/False
indice = df_treino.LABEL_TARGET == 1
indice
# Out:
# 0        False
# 1         True
# 2        False
# 5        False
# 6        False
#          ...
# 11492    False
# 11494    False
# 11495    False
# 11496    False
# 11497    False
# Name: LABEL_TARGET, Length: 8050, dtype: bool

# %%
# Define valores positivos e negativos do índice
df_train_pos = df_treino.loc[indice]
df_train_neg = df_treino.loc[~indice]
df_train_pos
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 1     -340 -381 -376 -336 -275 -204 -131  -70  -16   20  ...   114   -39
# 8     -214 -269 -319 -343 -349 -345 -339 -356 -380 -466  ...  -644  -522
# 10    -370 -326  -38  341  730  959  969  905  789  654  ...  -343  -343
# 17    -264 -189 -117  -45   20   70  111  143  161  179  ...  -231  -221
# 19    -260 -257 -254 -243 -227 -211 -210 -213 -220 -233  ...   250   322
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11448  -26 -451 -414 -403  -41  104  156  304  432  485  ...   222   236
# 11457 -311  162  506  699  620  443  217   21 -169 -208  ...   404   351
# 11466 -400 -609 -694 -662 -580 -442 -299 -180  -56   78  ...   256   269
# 11467   16 -115 -206 -260 -278 -269 -257 -240 -218 -179  ...   -25   -30
# 11488 -985 -594 -120  308  620  644  538  320  116  -62  ...  -700  -351
#
#        X172  X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 1      -185  -293  -351  -379  -380  -350  -308             1
# 8      -321   -26   292   547   710   774   749             1
# 10     -347  -349  -357  -365  -379  -396  -403             1
# 17     -248  -321  -444  -530  -548  -536  -486             1
# 19      247   -13    -4    14   333   537   602             1
# ...     ...   ...   ...   ...   ...   ...   ...           ...
# 11448   196   148   158   259   400   530   567             1
# 11457    63  -376  -819  -866  -658  -346   -64             1
# 11466   216   128    85    98   198   323   411             1
# 11467   -29   -29   -10    19    51    76    87             1
# 11488  -214  -103   -26   -63  -213  -447  -686             1
#
# [1606 rows x 179 columns]

# %%
df_train_neg
# Out:
#         X1   X2   X3   X4   X5   X6  X7  X8  X9  X10  ...  X170  X171  X172  \
# 0      -94 -106 -116 -114  -94  -65 -39 -15   1   10  ...   -30   -26   -25
# 2      -98  -89  -73  -62  -46  -33 -51 -66 -78  -59  ...    60    18     3
# 5      -50  -55  -50  -49  -46  -48 -41 -45 -52  -60  ...   -32   -32   -36
# 6       11  -30  -66  -99 -108 -100 -89 -88 -94  -95  ...   -98   -90   -68
# 11      29   12  -15  -42  -50  -36 -38 -14  -4    6  ...   -26   -36   -63
# ...    ...  ...  ...  ...  ...  ...  ..  ..  ..  ...  ...   ...   ...   ...
# 11492  110   83   75   79   87   89  53  31 -13  -32  ...    33    50    66
# 11494    2  -15  -11   19   30   53  25  -4 -28  -47  ...    30    26    11
# 11495   17  -24  -61  -81  -84  -72 -69 -60 -55  -40  ...    -4    20    38
# 11496   -2    2   13   51   76   97  70  40  17    1  ...    34    25    22
# 11497   -4  -12  -10  -21  -12   -3   0 -15 -18  -32  ...  -103   -97   -85
#
#        X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 0       -36   -59   -78  -100  -118  -124             0
# 2        -6   -20   -50   -70   -65   -48             0
# 5       -33   -27   -19   -11    -8    -6             0
# 6       -52   -45   -50   -59   -57   -35             0
# 11     -101  -114  -111   -92   -77   -50             0
# ...     ...   ...   ...   ...   ...   ...           ...
# 11492    63    54    46    42    46    52             0
# 11494    16    -5   -11   -23   -17   -11             0
# 11495    40     6   -55   -99   -99   -47             0
# 11496    13    11     8    15    24     9             0
# 11497   -78   -64   -51   -38   -51   -62             0
#
# [6444 rows x 179 columns]

# %%
# Valor mínimo de registros entre classe positiva e negativa
valor_minimo = np.min([len(df_train_pos), len(df_train_neg)])

valor_minimo
# Out:
# 1606

# %%
# Obtém valores aleatórios para o dataset de treino
df_treino_final = pd.concat([df_train_pos.sample(n = valor_minimo, random_state = 69), 
                             df_train_neg.sample(n = valor_minimo, random_state = 69)], 
                            axis = 0, 
                            ignore_index = True)

df_treino_final
# Out:
#        X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  X172  \
# 0    -131 -150 -190 -223 -201 -141  -44   58  139  196  ...   -38  -166  -262
# 1    -595 -534 -443 -335 -230 -120  -14   65  102  111  ...   -35  -130  -249
# 2    -658 -259   93  369  547  630  627  564  470  370  ... -1860 -1820 -1495
# 3     -89  -93  -95 -103 -109 -109  -78   -6   86  179  ...  -137  -131   -72
# 4     413  301  222  173  156  153  153  155  160  170  ...   211   181   154
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 3207  -53  -64  -59  -49  -45  -64  -78  -72  -54  -41  ...    56   101   146
# 3208   97   99   99   95   78   51   65   84   93   91  ...   104    97    85
# 3209  -28   -8    8   10    8    6   -1    9   23   38  ...   -38   -37   -26
# 3210  -78  -93 -117 -130 -126  -66    9   77  143  133  ...   -20   -60   -69
# 3211   65   91  105  101   93   64   53   49   16    1  ...   -89  -115  -139
#
#       X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 0     -196   -87   -81  -118  -175  -261             1
# 1     -395  -486  -470  -377  -276  -167             1
# 2     -972  -504  -130   170   382   500             1
# 3      -10    19    29    62   108   142             1
# 4       45  -127  -373  -647  -874  -962             1
# ...    ...   ...   ...   ...   ...   ...           ...
# 3207   146   108    58    22     4    -8             0
# 3208    57    43    34    38    51    48             0
# 3209   -21    -4     9    14     3   -17             0
# 3210   -74   -65   -40   -12     0    -1             0
# 3211  -161  -144  -105   -74   -29    26             0
#
# [3212 rows x 179 columns]

# %%
# Embaralhando o dataset anterior
df_treino_final = df_treino_final.sample(n = len(df_treino_final), random_state = 69).reset_index(drop = True)
df_treino_final
# Out:
#        X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  X172  \
# 0      23   31   33   27   22    5   -2   -6  -12  -17  ...   -71   -82   -97
# 1    -109 -113 -119 -123 -124 -123 -120 -103  -92  -74  ...    86    96    89
# 2     -75  -80  -83  -83  -81  -74  -63  -44  -42  -54  ...   -32   -40   -52
# 3     -70 -238 -370 -408 -360 -278 -196 -125  -55    5  ...   247   161   113
# 4    -126 -189 -223 -250 -273 -299 -331 -349 -367 -380  ...  -351  -438  -792
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 3207  -89  -76  -49  -32  -17  -12  -11  -13  -12  -20  ...   -19   -15   -19
# 3208  -36  -26  -23  -22  -27  -31  -25  -23  -16  -12  ...   182   145   143
# 3209 -173 -162 -140 -118  -91  -61  -37  -24  -17  -13  ...  -253  -265  -278
# 3210  -16   -8   -1    0   14   12  -10  -39  -51  -64  ...  -100  -106  -100
# 3211   -5  -29  -49  -70  -79  -84  -83  -81  -71  -47  ...    59    56    23
#
#       X173  X174  X175  X176  X177  X178  LABEL_TARGET
# 0     -105  -111  -101   -86   -66   -41             0
# 1       59    31    21    17     7    -5             0
# 2      -71   -97  -127  -153  -172  -178             0
# 3       93   108    44   -75  -225  -371             1
# 4    -1126 -1185  -781    14   689  1122             1
# ...    ...   ...   ...   ...   ...   ...           ...
# 3207   -28   -46   -58   -67   -71   -75             0
# 3208   156   194   242   282   321   338             1
# 3209  -287  -295  -312  -327  -357  -427             0
# 3210   -94  -101   -95   -84   -66   -56             0
# 3211   -16   -48   -79   -97  -106  -102             0
#
# [3212 rows x 179 columns]

# %%
df_treino_final.shape
# Out:
# (3212, 179)

# %%
# balanceamento dos dados de treino
df_treino_final.LABEL_TARGET.value_counts()
# Out:
# 0    1606
# 1    1606
# Name: LABEL_TARGET, dtype: int64

# %%
# balanceamento dos dados de treino

df_treino_final.LABEL_TARGET.value_counts(normalize=True)
# Out:
# 0    0.5
# 1    0.5
# Name: LABEL_TARGET, dtype: float64

# %% [markdown]
# <p style='text-align: justify;'>
#   ________________________________________
# </p>
#
# <h4 style='text-align: justify;'>
# Salvando as Bases do Resultado do Pré-Processamento
# </h4>
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
# Salvamos todos os datasets em disco no formato csv
df_treino.to_csv('dados/dados_treino.csv', index = False)
df_treino_final.to_csv('dados/dados_treino_final.csv', index = False)
df_valid.to_csv('dados/dados_valid.csv', index = False)
df_teste.to_csv('dados/dados_teste.csv', index = False)

# %%
# Salvamos os nomes dos dados de entrada (colunas preditoras) para facilitar a utilização mais tarde
pickle.dump(colunas_entrada, open('dados/colunas_entrada.sav', 'wb'))

# %% [markdown]
# <p style='text-align: justify;'>
#   ________________________________________
# </p>
#
# <p style='text-align: justify;'>
# A parte da modelagem é tratada no próximo script.
# </p>
#
# <p style='text-align: justify;'>
#   ________________________________________
# </p>

# %%
# %reload_ext watermark
# %watermark -a "Michela Camboim"
# Out:
# Author: Michela Camboim

# %%
# %watermark -v -m
# Out:
# Python implementation: CPython
# Python version       : 3.10.13
# IPython version      : 8.15.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 142 Stepping 12, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit

# %%
# %watermark --iversions
# Out:
# pandas: 1.5.3
# numpy : 1.25.2
